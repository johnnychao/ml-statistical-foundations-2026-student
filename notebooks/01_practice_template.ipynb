# %% [markdown]
# # 實作模板
#
# 請將本 notebook 複製後改名，再依照課堂任務填寫。

# %%
# Colab 專用前置檢查：如果缺少 ISLP，就自動安裝。
# 本機 Jupyter 通常已透過 scripts/setup_env.ps1 安裝，不會自動改動你的環境。
import importlib.util
import subprocess
import sys

if importlib.util.find_spec("ISLP") is None:
    if "google.colab" in sys.modules:
        print("Colab 尚未安裝 ISLP，現在自動安裝。")
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", "ISLP"])
        print("ISLP 安裝完成，請繼續執行下一格。")
    else:
        raise ModuleNotFoundError("No module named ISLP. 請先執行 scripts/setup_env.ps1，或手動安裝 ISLP。")
else:
    print("ISLP 已安裝，可以繼續執行練習模板。")

# %% [markdown]
# ## 1. 問題目標
#
# - 本次任務是 prediction、interpretation，還是 exploration？
# - 目標變數是什麼？如果沒有目標變數，想探索什麼結構？
# - 成功的模型或分析應該如何評估？

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ISLP import load_data

# %% [markdown]
# ## 2. 資料讀取與檢查

# %%
# TODO: 請依課堂任務更換資料集名稱
data = load_data('Auto')
data.head()

# %%
print(data.shape)
data.info()

# %% [markdown]
# ## 3. 初步探索
#
# - 觀察變數分布。
# - 檢查缺失值。
# - 畫出與任務相關的圖。

# %%
data.describe(include='all')

# %% [markdown]
# ## 4. 模型或分析流程
#
# 請依課堂任務建立 baseline，再逐步改善。

# %%
# TODO: 建立模型、驗證或分析流程

# %% [markdown]
# ## 5. 結果解釋與限制
#
# - 主要結果是什麼？
# - 模型或分析有哪些限制？
# - 哪些結論不能解釋成因果？
# - 下一步可以怎麼改善？
